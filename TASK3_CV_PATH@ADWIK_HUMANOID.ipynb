# %%
import numpy as np
import math
import pandas as pd
import cv2 as cv 
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage.exposure import rescale_intensity
from PIL import Image 
import matplotlib.pylab as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cap = cv.VideoCapture('/content/drive/MyDrive/line video.mp4')

# %%
fps = cap.get(cv.CAP_PROP_FPS)
print('frames per second =',fps)
# Out:
# frames per second = 30.0

# %%
frame_num = (int)(cap.get(cv.CAP_PROP_FRAME_COUNT))

print("number of frames = ",frame_num)
# Out:
# number of frames =  1354

# %%
cap.set(cv.CAP_PROP_POS_FRAMES, 500)
ret, frame = cap.read()
cv2_imshow(frame)
print(frame.shape)
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080 at 0x7FF21A1A2BC0>
# (1080, 1920, 3)

# %%
direction = []

for frame_id in range(frame_num//20):
  cap.set(cv.CAP_PROP_POS_FRAMES, frame_id*20)
  ret, frame = cap.read()
  frame_bw = cv.cvtColor(frame ,cv.COLOR_BGR2GRAY)
  count_right = 0
  count_left = 0
  for i in range(frame_bw.shape[1]):
    if i<(frame_bw.shape[1])//2:
      for j in range(frame_bw.shape[0]//10):
        if frame_bw[j*10,i]<100:
          count_left = count_left + 1
    if i>(frame_bw.shape[1])//2:
      for j in range(frame_bw.shape[0]//10):
        if frame_bw[j*10,i]<100:
  #        count_right = count_right + 1
  #if count_left > count_right:
  #  direction.append("LEFT")
  #else:
  #  direction.append("RIGHT")

# %%
for i in range(frame_num//20):
  print(f"at time = {i*20/30} turn {direction[i]}")
# Out:
# at time = 0.0 turn LEFT
# at time = 0.6666666666666666 turn LEFT
# at time = 1.3333333333333333 turn LEFT
# at time = 2.0 turn LEFT
# at time = 2.6666666666666665 turn RIGHT
# at time = 3.3333333333333335 turn LEFT
# at time = 4.0 turn RIGHT
# at time = 4.666666666666667 turn RIGHT
# at time = 5.333333333333333 turn RIGHT
# at time = 6.0 turn LEFT
# at time = 6.666666666666667 turn LEFT
# at time = 7.333333333333333 turn LEFT
# at time = 8.0 turn LEFT
# at time = 8.666666666666666 turn LEFT
# at time = 9.333333333333334 turn LEFT
# at time = 10.0 turn LEFT
# at time = 10.666666666666666 turn LEFT
# at time = 11.333333333333334 turn LEFT
# at time = 12.0 turn LEFT
# at time = 12.666666666666666 turn LEFT
# at time = 13.333333333333334 turn LEFT
# at time = 14.0 turn LEFT
# at time = 14.666666666666666 turn LEFT
# at time = 15.333333333333334 turn LEFT
# at time = 16.0 turn LEFT
# at time = 16.666666666666668 turn LEFT
# at time = 17.333333333333332 turn LEFT
# ...
